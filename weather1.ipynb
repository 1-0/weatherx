# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# http://rp5.ua/archive.php?wmo_id=34300&lang=ru
# lt_kh - local Kharkov Time, a30 - end
COLUM_NAME = [
    "lt_kh","T","Po","P","Pa","U","DD","Ff","ff10","ff3","N","WW","W1","W2","Tn","Tx","Cl","Nh","H","Cm","Ch","VV","Td","RRR","tR","E","Tg","E'","sss","a30"
    ]

# %%
def show_extrems(df, freq):
    dataf = d.groupby(pd.Grouper(key="lt_kh", freq=freq)).mean()
    
    
    plt.plot(dataf['T'])
    plt.show()
    
    plt.plot(dataf['Ff'])
    plt.show()
    
    plt.plot(dataf['tR'])
    plt.show()
    
    ##print(dataf)
    dataf_max = np.max(dataf,axis=0)
    print("freq", freq, "data frame max ----->\n", dataf_max)
    dataf_min = np.min(dataf,axis=0)
    print("freq", freq, "data frame min ---->\n", dataf_min)

# %%
if __name__ == "__main__":
    d = pd.read_csv(
                       '34300.01.01.2016.01.01.2017.1.0.0.ru.csv.gz', 
                       comment='#', 
                       parse_dates=[0, ], 
                       skiprows=[0, 1, 2, 3 , 4, 5, 6],
                       delimiter=';',
                       names = COLUM_NAME,
                       compression='gzip',
                       error_bad_lines=False
                      )
    print(d)
    print("np.max(d,axis=0)[1]", np.max(d,axis=0)[1])
    print("np.min(d,axis=0)[1]", np.min(d,axis=0)[1])

    show_extrems(d, '1M')
    show_extrems(d, '1W')
    show_extrems(d, '1D')
# Out:
#                    lt_kh     T     Po      P   Pa      U  \
# 0    2017-01-01 23:00:00  -2.0  744.5  759.1 -0.5  100.0
# 1    2017-01-01 20:00:00  -2.5  745.0  759.6 -0.1   98.0
# 2    2017-01-01 17:00:00  -3.3  745.1  759.8 -0.4   99.0
# 3    2017-01-01 14:00:00  -3.8  745.5  760.2 -0.7   96.0
# 4    2017-01-01 11:00:00  -4.1  746.2  760.9 -0.5   96.0
# 5    2017-01-01 08:00:00  -5.4  746.7  761.5 -0.2   98.0
# 6    2017-01-01 05:00:00  -4.6  746.9  761.7 -1.5  100.0
# 7    2017-01-01 02:00:00  -4.8  748.4  763.3 -1.2   98.0
# 8    2016-12-31 23:00:00  -4.8  749.6  764.5 -1.1   96.0
# 9    2016-12-31 20:00:00  -6.0  750.7  765.7 -0.7   92.0
# 10   2016-12-31 17:00:00  -4.6  751.4  766.3 -1.2   89.0
# 11   2016-12-31 14:00:00  -3.8  752.6  767.5 -2.1   87.0
# 12   2016-12-31 11:00:00  -6.2  754.7  769.8 -1.6   94.0
# 13   2016-12-31 08:00:00  -9.4  756.3  771.6 -0.4   95.0
# 14   2016-12-31 05:00:00  -7.8  756.7  772.0 -1.3   96.0
# 15   2016-12-31 02:00:00  -7.4  758.0  773.2 -1.4   93.0
# 16   2016-12-30 23:00:00  -7.0  759.4  774.6 -0.4   91.0
# 17   2016-12-30 20:00:00  -6.6  759.8  775.0  0.1   94.0
# 18   2016-12-30 17:00:00  -4.7  759.7  774.7 -0.6   86.0
# 19   2016-12-30 14:00:00  -2.2  760.3  775.3 -0.6   77.0
# 20   2016-12-30 11:00:00  -2.0  760.9  775.8  0.2   88.0
# 21   2016-12-30 08:00:00  -1.5  760.7  775.6  0.4   90.0
# 22   2016-12-30 05:00:00  -1.1  760.3  775.2  0.0   91.0
# 23   2016-12-30 02:00:00  -0.7  760.3  775.2  0.4   91.0
# 24   2016-12-29 23:00:00  -0.6  759.9  774.7  1.2   92.0
# 25   2016-12-29 20:00:00  -0.3  758.7  773.5  1.4   90.0
# 26   2016-12-29 17:00:00   0.1  757.3  772.1  1.3   84.0
# 27   2016-12-29 14:00:00   0.8  756.0  770.7  1.4   85.0
# 28   2016-12-29 11:00:00  -0.2  754.6  769.3  1.2   90.0
# 29   2016-12-29 08:00:00  -0.1  753.4  768.1  2.1   82.0
# ...                  ...   ...    ...    ...  ...    ...
# 2905 2016-04-01 17:00:00 -18.7  746.9  762.6 -0.3   80.0
# 2906 2016-04-01 14:00:00 -16.6  747.2  762.7 -0.9   78.0
# 2907 2016-04-01 11:00:00 -19.1  748.1  763.8 -0.6   81.0
# 2908 2016-04-01 08:00:00 -21.7  748.7  764.6 -0.8   83.0
# 2909 2016-04-01 05:00:00 -21.1  749.5  765.3 -1.1   81.0
# 2910 2016-04-01 02:00:00 -20.4  750.6  766.4 -0.7   81.0
# 2911 2016-03-01 23:00:00 -19.0  751.3  767.1 -0.6   81.0
# 2912 2016-03-01 20:00:00 -18.4  751.9  767.7 -0.9   71.0
# 2913 2016-03-01 17:00:00 -16.9  752.8  768.5 -0.3   78.0
# 2914 2016-03-01 14:00:00 -15.2  753.1  768.7 -0.9   71.0
# 2915 2016-03-01 11:00:00 -17.1  754.0  769.7 -1.0   81.0
# 2916 2016-03-01 08:00:00 -20.4  755.0  770.9 -0.8   83.0
# 2917 2016-03-01 05:00:00 -20.0  755.8  771.7 -0.8   81.0
# 2918 2016-03-01 02:00:00 -19.5  756.6  772.5 -0.7   82.0
# 2919 2016-02-01 23:00:00 -17.4  757.3  773.2 -0.8   83.0
# 2920 2016-02-01 20:00:00 -15.6  758.1  773.8 -0.4   80.0
# 2921 2016-02-01 17:00:00 -15.4  758.5  774.2 -0.3   80.0
# 2922 2016-02-01 14:00:00 -13.8  758.8  774.4 -0.2   75.0
# 2923 2016-02-01 11:00:00 -14.7  759.0  774.7  0.1   79.0
# 2924 2016-02-01 08:00:00 -17.6  758.9  774.7  0.6   80.0
# 2925 2016-02-01 05:00:00 -16.4  758.3  774.1  0.4   81.0
# 2926 2016-02-01 02:00:00 -15.4  757.9  773.6  0.2   80.0
# 2927 2016-01-01 23:00:00 -14.7  757.7  773.3 -0.1   80.0
# 2928 2016-01-01 20:00:00 -14.4  757.8  773.4  0.5   78.0
# 2929 2016-01-01 17:00:00 -13.0  757.3  772.8  0.7   79.0
# 2930 2016-01-01 14:00:00 -12.0  756.6  772.0 -0.1   70.0
# 2931 2016-01-01 11:00:00 -12.3  756.7  772.1  0.5   71.0
# 2932 2016-01-01 08:00:00 -12.6  756.2  771.7  0.3   80.0
# 2933 2016-01-01 05:00:00 -12.1  755.9  771.4  0.1   79.0
# 2934 2016-01-01 02:00:00 -11.8  755.8  771.2 -0.3   79.0
#
#                                          DD  Ff  ff10  ff3  ...  \
# 0                Ветер, дующий с юго-запада   4   NaN  NaN  ...
# 1                Ветер, дующий с юго-запада   3   NaN  NaN  ...
# 2                Ветер, дующий с юго-запада   2   NaN  NaN  ...
# 3         Ветер, дующий с западо-юго-запада   3   NaN  NaN  ...
# 4         Ветер, дующий с западо-юго-запада   3   NaN  NaN  ...
# 5                Ветер, дующий с юго-запада   3   NaN  NaN  ...
# 6            Ветер, дующий с юго-юго-запада   3   NaN  NaN  ...
# 7                Ветер, дующий с юго-запада   3   NaN  NaN  ...
# 8         Ветер, дующий с западо-юго-запада   3   NaN  NaN  ...
# 9                Ветер, дующий с юго-запада   3   NaN  NaN  ...
# 10           Ветер, дующий с юго-юго-запада   3   NaN  NaN  ...
# 11           Ветер, дующий с юго-юго-запада   3   NaN  NaN  ...
# 12           Ветер, дующий с юго-юго-запада   3   NaN  NaN  ...
# 13           Ветер, дующий с юго-юго-запада   3   NaN  NaN  ...
# 14                   Ветер, дующий с запада   2   NaN  NaN  ...
# 15               Ветер, дующий с юго-запада   1   NaN  NaN  ...
# 16        Ветер, дующий с западо-юго-запада   2   NaN  NaN  ...
# 17        Ветер, дующий с западо-юго-запада   2   NaN  NaN  ...
# 18                         Штиль, безветрие   0   NaN  NaN  ...
# 19                   Ветер, дующий с севера   4   NaN  NaN  ...
# 20            Ветер, дующий с северо-запада   2   NaN  NaN  ...
# 21     Ветер, дующий с северо-северо-запада   2   NaN  NaN  ...
# 22                   Ветер, дующий с севера   3   NaN  NaN  ...
# 23                   Ветер, дующий с севера   4   NaN  NaN  ...
# 24                   Ветер, дующий с севера   5   NaN  NaN  ...
# 25                   Ветер, дующий с севера   5   NaN  NaN  ...
# 26                   Ветер, дующий с севера   5   NaN  NaN  ...
# 27                   Ветер, дующий с севера   5   NaN  NaN  ...
# 28                   Ветер, дующий с севера   4   NaN  NaN  ...
# 29            Ветер, дующий с северо-запада   3   NaN  NaN  ...
# ...                                     ...  ..   ...  ...  ...
# 2905                    Ветер, дующий с юга   2   NaN  NaN  ...
# 2906      Ветер, дующий с западо-юго-запада   3   NaN  NaN  ...
# 2907                 Ветер, дующий с запада   3   NaN  NaN  ...
# 2908      Ветер, дующий с западо-юго-запада   3   NaN  NaN  ...
# 2909                 Ветер, дующий с запада   2   NaN  NaN  ...
# 2910                 Ветер, дующий с запада   3   NaN  NaN  ...
# 2911                 Ветер, дующий с запада   3   NaN  NaN  ...
# 2912                 Ветер, дующий с запада   4   NaN  NaN  ...
# 2913   Ветер, дующий с западо-северо-запада   3   NaN  NaN  ...
# 2914          Ветер, дующий с северо-запада   3   NaN  NaN  ...
# 2915   Ветер, дующий с западо-северо-запада   2   NaN  NaN  ...
# 2916   Ветер, дующий с западо-северо-запада   2   NaN  NaN  ...
# 2917                 Ветер, дующий с запада   2   NaN  NaN  ...
# 2918   Ветер, дующий с западо-северо-запада   2   NaN  NaN  ...
# 2919   Ветер, дующий с северо-северо-запада   2   NaN  NaN  ...
# 2920                 Ветер, дующий с севера   3   NaN  NaN  ...
# 2921                 Ветер, дующий с севера   3   NaN  NaN  ...
# 2922         Ветер, дующий с северо-востока   4   NaN  NaN  ...
# 2923         Ветер, дующий с северо-востока   2   NaN  NaN  ...
# 2924         Ветер, дующий с северо-востока   3   NaN  NaN  ...
# 2925         Ветер, дующий с северо-востока   3   NaN  NaN  ...
# 2926         Ветер, дующий с северо-востока   3   NaN  NaN  ...
# 2927  Ветер, дующий с северо-северо-востока   3   NaN  NaN  ...
# 2928         Ветер, дующий с северо-востока   4   NaN  NaN  ...
# 2929         Ветер, дующий с северо-востока   3   NaN  NaN  ...
# 2930  Ветер, дующий с северо-северо-востока   4   NaN  NaN  ...
# 2931                Ветер, дующий с востока   5   NaN  NaN  ...
# 2932  Ветер, дующий с северо-северо-востока   3   NaN  NaN  ...
# 2933  Ветер, дующий с северо-северо-востока   3   NaN  NaN  ...
# 2934  Ветер, дующий с северо-северо-востока   3   NaN  NaN  ...
#
#                                                      Ch    VV    Td  \
# 0                                                   NaN   0.5  -2.0
# 1                                                   NaN   1.2  -2.8
# 2                                                   NaN   0.7  -3.4
# 3                                                   NaN   2.8  -4.3
# 4                                                   NaN   2.8  -4.6
# 5                                                   NaN   2.8  -5.7
# 6                                                   NaN   0.8  -4.6
# 7                                                   NaN   1.7  -5.1
# 8                                                   NaN   2.4  -5.4
# 9                                                   NaN   5.0  -7.1
# 10                                                  NaN   4.0  -6.2
# 11    Перистых, перисто-кучевых или перисто-слоистых...  10.0  -5.6
# 12                                                  NaN   4.0  -7.0
# 13    Перистые нитевидные, иногда когтевидные, не ра...   4.0 -10.1
# 14    Перистых, перисто-кучевых или перисто-слоистых...   4.0  -8.4
# 15    Перистых, перисто-кучевых или перисто-слоистых...   4.0  -8.3
# 16    Перистые нитевидные, иногда когтевидные, не ра...   4.0  -8.3
# 17    Перистые нитевидные, иногда когтевидные, не ра...   2.7  -7.4
# 18    Перистые нитевидные, иногда когтевидные, не ра...  10.0  -6.7
# 19    Перистые нитевидные, иногда когтевидные, не ра...  10.0  -5.8
# 20    Перистые нитевидные, иногда когтевидные, не ра...   4.0  -3.8
# 21    Перистых, перисто-кучевых или перисто-слоистых...   4.0  -2.9
# 22                                                  NaN   4.0  -2.4
# 23                                                  NaN  10.0  -2.0
# 24    Перистых, перисто-кучевых или перисто-слоистых...  10.0  -1.8
# 25                                                  NaN  10.0  -1.8
# 26                                                  NaN  10.0  -2.3
# 27                                                  NaN  10.0  -1.5
# 28                                                  NaN  10.0  -1.7
# 29                                                  NaN  10.0  -2.8
# ...                                                 ...   ...   ...
# 2905  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -21.3
# 2906  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -19.5
# 2907  Перистые нитевидные, иногда когтевидные, не ра...  10.0 -21.5
# 2908  Перистые когтевидные или нитевидные или первые...  10.0 -23.8
# 2909                                                NaN  10.0 -23.5
# 2910                                                NaN  10.0 -22.8
# 2911                                                NaN  10.0 -21.4
# 2912                                                NaN   4.0 -22.4
# 2913  Перистые нитевидные, иногда когтевидные, не ра...  10.0 -19.8
# 2914  Перистые нитевидные, иногда когтевидные, не ра...  10.0 -19.3
# 2915                                                NaN  10.0 -19.6
# 2916  Перистых, перисто-кучевых или перисто-слоистых...   5.0 -22.5
# 2917  Перистых, перисто-кучевых или перисто-слоистых...   3.3 -22.4
# 2918  Перистых, перисто-кучевых или перисто-слоистых...   3.5 -21.8
# 2919  Перистых, перисто-кучевых или перисто-слоистых...   4.0 -19.6
# 2920  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -18.3
# 2921                                                NaN  10.0 -18.1
# 2922  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -17.3
# 2923  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -17.5
# 2924  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -20.2
# 2925  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -18.9
# 2926                                                NaN  10.0 -18.1
# 2927                                                NaN  10.0 -17.4
# 2928                                                NaN  10.0 -17.5
# 2929  Перистых, перисто-кучевых или перисто-слоистых...   4.3 -15.9
# 2930  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -16.4
# 2931  Перистых, перисто-кучевых или перисто-слоистых...  10.0 -16.5
# 2932  Перистых, перисто-кучевых или перисто-слоистых...   4.0 -15.3
# 2933                                                NaN  10.0 -15.1
# 2934                                                NaN  10.0 -14.7
#
#                 RRR    tR    E  Tg  \
# 0               NaN   NaN  NaN NaN
# 1     Следы осадков  12.0  NaN NaN
# 2               NaN   NaN  NaN NaN
# 3               NaN   NaN  NaN NaN
# 4               NaN   NaN  NaN NaN
# 5     Следы осадков  12.0  NaN NaN
# 6               NaN   NaN  NaN NaN
# 7     Следы осадков   6.0  NaN NaN
# 8               NaN   NaN  NaN NaN
# 9               NaN   NaN  NaN NaN
# 10              NaN   NaN  NaN NaN
# 11              NaN   NaN  NaN NaN
# 12              NaN   NaN  NaN NaN
# 13              NaN   NaN  NaN NaN
# 14              NaN   NaN  NaN NaN
# 15              NaN   NaN  NaN NaN
# 16              NaN   NaN  NaN NaN
# 17              NaN   NaN  NaN NaN
# 18              NaN   NaN  NaN NaN
# 19              NaN   NaN  NaN NaN
# 20              NaN   NaN  NaN NaN
# 21              NaN   NaN  NaN NaN
# 22              NaN   NaN  NaN NaN
# 23              NaN   NaN  NaN NaN
# 24              NaN   NaN  NaN NaN
# 25    Следы осадков  12.0  NaN NaN
# 26              NaN   NaN  NaN NaN
# 27    Следы осадков   6.0  NaN NaN
# 28              NaN   NaN  NaN NaN
# 29    Следы осадков  12.0  NaN NaN
# ...             ...   ...  ...  ..
# 2905            NaN   NaN  NaN NaN
# 2906  Следы осадков   6.0  NaN NaN
# 2907            NaN   NaN  NaN NaN
# 2908            NaN   NaN  NaN NaN
# 2909            NaN   NaN  NaN NaN
# 2910            NaN   NaN  NaN NaN
# 2911            NaN   NaN  NaN NaN
# 2912            NaN   NaN  NaN NaN
# 2913            NaN   NaN  NaN NaN
# 2914            NaN   NaN  NaN NaN
# 2915            NaN   NaN  NaN NaN
# 2916  Следы осадков  12.0  NaN NaN
# 2917            NaN   NaN  NaN NaN
# 2918  Следы осадков   6.0  NaN NaN
# 2919            NaN   NaN  NaN NaN
# 2920            NaN   NaN  NaN NaN
# 2921            NaN   NaN  NaN NaN
# 2922            NaN   NaN  NaN NaN
# 2923            NaN   NaN  NaN NaN
# 2924            0.7  12.0  NaN NaN
# 2925            NaN   NaN  NaN NaN
# 2926            0.5   6.0  NaN NaN
# 2927            NaN   NaN  NaN NaN
# 2928  Следы осадков  12.0  NaN NaN
# 2929            NaN   NaN  NaN NaN
# 2930  Следы осадков   6.0  NaN NaN
# 2931            NaN   NaN  NaN NaN
# 2932            0.2  12.0  NaN NaN
# 2933            NaN   NaN  NaN NaN
# 2934  Следы осадков   6.0  NaN NaN
#
#                                                      E'   sss a30
# 0                                                   NaN   NaN NaN
# 1                                                   NaN   NaN NaN
# 2                                                   NaN   NaN NaN
# 3                                                   NaN   NaN NaN
# 4                                                   NaN   NaN NaN
# 5     Ровный слой слежавшегося или мокрого снега пок...   9.0 NaN
# 6                                                   NaN   NaN NaN
# 7                                                   NaN   NaN NaN
# 8                                                   NaN   NaN NaN
# 9                                                   NaN   NaN NaN
# 10                                                  NaN   NaN NaN
# 11                                                  NaN   NaN NaN
# 12                                                  NaN   NaN NaN
# 13    Ровный слой слежавшегося или мокрого снега пок...   9.0 NaN
# 14                                                  NaN   NaN NaN
# 15                                                  NaN   NaN NaN
# 16                                                  NaN   NaN NaN
# 17                                                  NaN   NaN NaN
# 18                                                  NaN   NaN NaN
# 19                                                  NaN   NaN NaN
# 20                                                  NaN   NaN NaN
# 21    Ровный слой слежавшегося или мокрого снега пок...   9.0 NaN
# 22                                                  NaN   NaN NaN
# 23                                                  NaN   NaN NaN
# 24                                                  NaN   NaN NaN
# 25                                                  NaN   NaN NaN
# 26                                                  NaN   NaN NaN
# 27                                                  NaN   NaN NaN
# 28                                                  NaN   NaN NaN
# 29    Ровный слой слежавшегося или мокрого снега пок...  10.0 NaN
# ...                                                 ...   ...  ..
# 2905                                                NaN   NaN NaN
# 2906                                                NaN   NaN NaN
# 2907                                                NaN   NaN NaN
# 2908  Ровный слой сухого рассыпчатого снега покрывае...   8.0 NaN
# 2909                                                NaN   NaN NaN
# 2910                                                NaN   NaN NaN
# 2911                                                NaN   NaN NaN
# 2912                                                NaN   NaN NaN
# 2913                                                NaN   NaN NaN
# 2914                                                NaN   NaN NaN
# 2915                                                NaN   NaN NaN
# 2916  Ровный слой сухого рассыпчатого снега покрывае...   8.0 NaN
# 2917                                                NaN   NaN NaN
# 2918                                                NaN   NaN NaN
# 2919                                                NaN   NaN NaN
# 2920                                                NaN   NaN NaN
# 2921                                                NaN   NaN NaN
# 2922                                                NaN   NaN NaN
# 2923                                                NaN   NaN NaN
# 2924  Ровный слой сухого рассыпчатого снега покрывае...   8.0 NaN
# 2925                                                NaN   NaN NaN
# 2926                                                NaN   NaN NaN
# 2927                                                NaN   NaN NaN
# 2928                                                NaN   NaN NaN
# 2929                                                NaN   NaN NaN
# 2930                                                NaN   NaN NaN
# 2931                                                NaN   NaN NaN
# 2932  Ровный слой сухого рассыпчатого снега покрывае...   8.0 NaN
# 2933                                                NaN   NaN NaN
# 2934                                                NaN   NaN NaN
#
# [2935 rows x 30 columns]
# np.max(d,axis=0)[1] 38.4
# np.min(d,axis=0)[1] -23.4
# c:\program\python37-32\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# freq 1M data frame max ----->
#  T        18.033468
# Po      753.489157
# P       767.863052
# Pa        0.073790
# U        98.125000
# Ff        4.325000
# ff10           NaN
# ff3      22.000000
# Tn       12.896667
# Tx       23.419355
# Td       11.138750
# tR       10.000000
# Tg        4.000000
# a30            NaN
# dtype: float64
# freq 1M data frame min ---->
#  T        -3.812500
# Po      744.549372
# P       758.485356
# Pa       -0.637500
# U        66.931452
# Ff        2.841667
# ff10           NaN
# ff3      18.000000
# Tn       -6.000000
# Tx       -2.500000
# Td       -4.062500
# tR        9.260870
# Tg       -2.000000
# a30            NaN
# dtype: float64
# freq 1W data frame max ----->
#  T        24.316071
# Po      761.494643
# P       776.133929
# Pa        0.351786
# U        92.035714
# Ff        5.089286
# ff10           NaN
# ff3      22.000000
# Tn       18.614286
# Tx       29.642857
# Td       16.271429
# tR       10.500000
# Tg        4.000000
# a30            NaN
# dtype: float64
# freq 1W data frame min ---->
#  T        -9.203571
# Po      741.278571
# P       754.673214
# Pa       -0.512500
# U        56.892857
# Ff        1.571429
# ff10           NaN
# ff3      18.000000
# Tn      -10.971429
# Tx       -6.742857
# Td      -10.925000
# tR        9.000000
# Tg       -2.000000
# a30            NaN
# dtype: float64
# freq 1D data frame max ----->
#  T        30.6375
# Po      767.5500
# P       782.5375
# Pa        1.6125
# U        98.8750
# Ff        9.6250
# ff10         NaN
# ff3      22.0000
# Tn       22.4000
# Tx       38.4000
# Td       19.1125
# tR       12.0000
# Tg        5.0000
# a30          NaN
# dtype: float64
# freq 1D data frame min ---->
#  T       -19.6125
# Po      734.1875
# P       748.4875
# Pa       -2.6875
# U        38.8750
# Ff        0.6250
# ff10         NaN
# ff3      18.0000
# Tn      -24.3000
# Tx      -16.6000
# Td      -21.9875
# tR        9.0000
# Tg       -2.0000
# a30          NaN
# dtype: float64

# %%
def show_extrems_column(df, freq, column, maximum):
    dataframe = df.groupby(pd.Grouper(key="lt_kh", freq=freq)).mean()
    if maximum:
        data = np.max(dataframe,axis=0)
    else:
        data = np.min(dataframe,axis=0)
    arr = dataframe[column]
    d = np.where(arr==data[column])
    
    try:
        res1, res2 = int(d[-1]), data[column]
    except TypeError:
        res1, res2 = d, data[column]
    return res1, res2

# %%
# 1. Найти самый ветреный месяц - (месяц и средняя скорость ветра)
# 2. Найти самый холодный месяц - (месяц и средняя температура)
# 3. Найти самый холодный день - (день и средняя температура)
# 4. Найти самый тёплый месяц - (месяц и средняя температура)
# 5. Найти самый тёплый день - (день и средняя температура)
# 6. Найти самую дождливую неделю - (период и количество осадков)
if __name__ == "__main__":
    d = pd.read_csv(
                       '34300.01.01.2016.01.01.2017.1.0.0.ru.csv.gz', 
                       comment='#', 
                       parse_dates=[0, ], 
                       skiprows=[0, 1, 2, 3 , 4, 5, 6],
                       delimiter=';',
                       names = COLUM_NAME,
                       compression='gzip',
                       error_bad_lines=False
                      )

    print("#1. Найти самый ветреный месяц - (месяц и средняя скорость ветра)", show_extrems_column(d, '1M', 'Ff', maximum = True))
    print("#2. Найти самый холодный месяц - (месяц и средняя температура)", show_extrems_column(d, '1M', 'T', maximum = False))
    print("#3. Найти самый холодный день - (день и средняя температура)", show_extrems_column(d, '1D', 'T', maximum = False))
    print("#4. Найти самый тёплый месяц - (месяц и средняя температура)", show_extrems_column(d, '1M', 'T', maximum = True))
    print("#5. Найти самый тёплый день - (день и средняя температура)", show_extrems_column(d, '1D', 'T', maximum = True))
    print("#6. Найти самую дождливую неделю - (период и количество осадков)", show_extrems_column(d, '1W', 'tR', maximum = True))
# Out:
# #1. Найти самый ветреный месяц - (месяц и средняя скорость ветра) (10, 4.325)
# #2. Найти самый холодный месяц - (месяц и средняя температура) (12, -3.8125)
# #3. Найти самый холодный день - (день и средняя температура) (91, -19.6125)
# #4. Найти самый тёплый месяц - (месяц и средняя температура) (6, 18.033467741935482)
# #5. Найти самый тёплый день - (день и средняя температура) (198, 30.637500000000003)
# #6. Найти самую дождливую неделю - (период и количество осадков) ((array([ 7, 30], dtype=int32),), 10.5)
